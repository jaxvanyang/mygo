# %%
# append the module root to Python path
import sys

sys.path.append("../src")

# %%
import time
import random
import itertools

from go.game import Game
from agent.naive import *
from agent.helper import *

# %%
# %%prun -l 15 -s cumulative

random.seed(25565)  # for reproducible output

size = 5
game = Game.new_game(size)
# TreeSearchBot vs. itself (with different search depth)
bots = (TreeSearchBot(2), TreeSearchBot(3))

start_time = time.perf_counter()

for i in itertools.count(1):
    if game.is_over:
        break

    move = bots[i % 2 ^ 1].select_move(game)
    game.apply_move(move)
    print(f"{game_to_str(game, i)}\n")

end_time = time.perf_counter()

print(f"\nwinner: {game.winner}\n")
print(f"time: {end_time - start_time:.3f}s")
# Out:
#    A B C D E
#  5 . . . . .  5
#  4 . .(X). .  4
#  3 . . . . .  3
#  2 . . . . .  2
#  1 . . . . .  1
#    A B C D E
#
# black(  1): C4
#
#    A B C D E
#  5 . . .(O).  5
#  4 . . X . .  4
#  3 . . . . .  3
#  2 . . . . .  2
#  1 . . . . .  1
#    A B C D E
#
# white(  2): D5
#
#    A B C D E
#  5 . . . O .  5
#  4 . . X . .  4
#  3 . . . . .  3
#  2 . . .(X).  2
#  1 . . . . .  1
#    A B C D E
#
# black(  3): D2
#
#    A B C D E
#  5 . . . O .  5
#  4 . . X . .  4
#  3 . . . . .  3
#  2 . . . X .  2
#  1(O). . . .  1
#    A B C D E
#
# white(  4): A1
#
#    A B C D E
#  5 . . . O .  5
#  4 . . X . .  4
#  3 .(X). . .  3
#  2 . . . X .  2
#  1 O . . . .  1
#    A B C D E
#
# black(  5): B3
#
#    A B C D E
#  5 . . . O .  5
#  4 . . X . .  4
#  3 . X . .(O) 3
#  2 . . . X .  2
#  1 O . . . .  1
#    A B C D E
#
# white(  6): E3
#
#    A B C D E
#  5 . . . O .  5
#  4 . . X . .  4
#  3 . X . . O  3
#  2 .(X). X .  2
#  1 O . . . .  1
#    A B C D E
#
# black(  7): B2
#
#    A B C D E
#  5 . . . O .  5
#  4 .(O)X . .  4
#  3 . X . . O  3
#  2 . X . X .  2
#  1 O . . . .  1
#    A B C D E
#
# white(  8): B4
#
#    A B C D E
#  5 . . . O .  5
#  4 . O X . .  4
#  3 . X . . O  3
#  2(X)X . X .  2
#  1 O . . . .  1
#    A B C D E
#
# black(  9): A2
#
#    A B C D E
#  5 . . . O .  5
#  4(O)O X . .  4
#  3 . X . . O  3
#  2 X X . X .  2
#  1 O . . . .  1
#    A B C D E
#
# white( 10): A4
#
#    A B C D E
#  5 . . . O .  5
#  4 O O X . .  4
#  3 . X . . O  3
#  2 X X . X(X) 2
#  1 O . . . .  1
#    A B C D E
#
# black( 11): E2
#
#    A B C D E
#  5 . . . O .  5
#  4 O O X . .  4
#  3 . X(O). O  3
#  2 X X . X X  2
#  1 O . . . .  1
#    A B C D E
#
# white( 12): C3
#
#    A B C D E
#  5 . . . O .  5
#  4 O O X . .  4
#  3(X)X O . O  3
#  2 X X . X X  2
#  1 O . . . .  1
#    A B C D E
#
# black( 13): A3
#
#    A B C D E
#  5 . . . O .  5
#  4 O O X(O).  4
#  3 X X O . O  3
#  2 X X . X X  2
#  1 O . . . .  1
#    A B C D E
#
# white( 14): D4
#
#    A B C D E
#  5 . . . O .  5
#  4 O O X O(X) 4
#  3 X X O . O  3
#  2 X X . X X  2
#  1 O . . . .  1
#    A B C D E
#
# black( 15): E4
#
#    A B C D E
#  5 . . . O(O) 5
#  4 O O X O .  4
#  3 X X O . O  3
#  2 X X . X X  2
#  1 O . . . .  1
#    A B C D E
#
# white( 16): E5
#
#    A B C D E
#  5 . . . O O  5
#  4 O O X O .  4
#  3 X X O . O  3
#  2 X X . X X  2
#  1 O . . .(X) 1
#    A B C D E
#
# black( 17): E1
#
#    A B C D E
#  5 . .(O)O O  5
#  4 O O . O .  4
#  3 X X O . O  3
#  2 X X . X X  2
#  1 O . . . X  1
#    A B C D E
#
# white( 18): C5
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O .  4
#  3 X X O(X)O  3
#  2 X X . X X  2
#  1 O . . . X  1
#    A B C D E
#
# black( 19): D3
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O .  4
#  3 X X O X O  3
#  2 X X(O)X X  2
#  1 O . . . X  1
#    A B C D E
#
# white( 20): C2
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O .  4
#  3 X X O X O  3
#  2 X X O X X  2
#  1 .(X). . X  1
#    A B C D E
#
# black( 21): B1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O(O) 4
#  3 X X O X O  3
#  2 X X O X X  2
#  1 . X . . X  1
#    A B C D E
#
# white( 22): E4
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 X X O X O  3
#  2 X X O X X  2
#  1 . X(X). X  1
#    A B C D E
#
# black( 23): C1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 X X O . O  3
#  2 X X O . .  2
#  1 . X X(O).  1
#    A B C D E
#
# white( 24): D1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 X X O . O  3
#  2 X X O(X).  2
#  1 . X X O .  1
#    A B C D E
#
# black( 25): D2
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . . O . O  3
#  2 . . O X .  2
#  1(O). . O .  1
#    A B C D E
#
# white( 26): A1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . . O . O  3
#  2 . . O X .  2
#  1 O(X). O .  1
#    A B C D E
#
# black( 27): B1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . . O . O  3
#  2(O). O X .  2
#  1 O X . O .  1
#    A B C D E
#
# white( 28): A2
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . . O . O  3
#  2 O . O X(X) 2
#  1 O X . O .  1
#    A B C D E
#
# black( 29): E2
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . . O . O  3
#  2 O . O X X  2
#  1 O X(O)O .  1
#    A B C D E
#
# white( 30): C1
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 .(X)O . O  3
#  2 O . O X X  2
#  1 O X O O .  1
#    A B C D E
#
# black( 31): B3
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . X O . O  3
#  2 O(O)O X X  2
#  1 O . O O .  1
#    A B C D E
#
# white( 32): B2
#
#    A B C D E
#  5 . . O O O  5
#  4 O O . O O  4
#  3 . X O . O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# black( 33): pass
#
#    A B C D E
#  5 . . O O O  5
#  4 O O(O)O O  4
#  3 . X O . O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# white( 34): C4
#
#    A B C D E
#  5 . . O O O  5
#  4 O O O O O  4
#  3 . X O . O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# black( 35): pass
#
#    A B C D E
#  5(O). O O O  5
#  4 O O O O O  4
#  3 . X O . O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# white( 36): A5
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 . X O . O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# black( 37): pass
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 . X O(O)O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# white( 38): D3
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 . X O O O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# black( 39): pass
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3(O). O O O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# white( 40): A3
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O X X  2
#  1 O . O O .  1
#    A B C D E
#
# black( 41): pass
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O . .  2
#  1 O . O O(O) 1
#    A B C D E
#
# white( 42): E1
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O . .  2
#  1 O . O O O  1
#    A B C D E
#
# black( 43): pass
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O(O).  2
#  1 O . O O O  1
#    A B C D E
#
# white( 44): D2
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O O .  2
#  1 O . O O O  1
#    A B C D E
#
# black( 45): pass
#
#    A B C D E
#  5 O . O O O  5
#  4 O O O O O  4
#  3 O . O O O  3
#  2 O O O O .  2
#  1 O . O O O  1
#    A B C D E
#
# white( 46): pass
#
#
# winner: white
#
# time: 37.895s
#          150755312 function calls (133982072 primitive calls) in 37.895 seconds
#
#    Ordered by: cumulative time
#    List reduced from 127 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   37.895   37.895 {built-in method builtins.exec}
#         1    0.000    0.000   37.895   37.895 <string>:1(<module>)
#        46    0.001    0.000   37.889    0.824 naive.py:72(select_move)
# 79258/431    0.300    0.000   37.840    0.088 naive.py:29(calc_move_score)
# 15088759/282550   11.925    0.000   29.324    0.000 copy.py:128(deepcopy)
# 599513/282550    1.247    0.000   28.157    0.000 copy.py:259(_reconstruct)
# 441041/282550    0.858    0.000   26.442    0.000 copy.py:227(_deepcopy_dict)
#     13364    0.021    0.000   20.128    0.002 game.py:253(good_moves)
# 1774558/361808    2.827    0.000   19.755    0.000 copy.py:201(_deepcopy_list)
#     13364    0.014    0.000   19.133    0.001 game.py:244(valid_plays)
#     13364    0.227    0.000   18.838    0.001 game.py:247(<listcomp>)
#    203292    0.559    0.000   18.386    0.000 game.py:284(is_valid_move)
#   1357454    0.263    0.000    4.876    0.000 copy.py:264(<genexpr>)
#    282588    1.144    0.000    3.446    0.000 game.py:135(place_stone)
#   1592132    1.341    0.000    3.130    0.000 types.py:114(__deepcopy__)
